# %% [markdown]
# This notebook includes some cleaning of the names that I extracted from notes files, matching between files, and matching to the master database. For the actual name extraction, see NER_from_notes.ipynb

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize
st = StanfordNERTagger('/Users/seb2244/Downloads/stanford-ner-4.0.0/classifiers/english.all.3class.distsim.crf.ser.gz',
               '/Users/seb2244/Downloads/stanford-ner-4.0.0/stanford-ner.jar') 

from itertools import groupby

# %%
import pandas as pd
import numpy as np
import os
os.chdir('/Users/seb2244/Desktop/migration_project/Research Notes for name (and date,place_) extraction')
import re

# %%
# for reading docx files
import docx2txt

# %%
# main problems: 
# 1. abbreviations beforehand and afterwards 
# 2. dashes and periods changing how names are demarcated, making them not seem like duplicates
# 3. normal duplicates
# 4. names together with commas like john johnson, jane smith being counted as one name

# %%
data = pd.read_excel("ner_8_9_20.xlsx")

# %%
data.reset_index(drop = True, inplace = True)

# %%
# 4. split up names that are 3 or more names with commas
# (2 or more is hard to do because like "du Bois, William E" could actually be one person)
rows_to_drop = []
for i in range(len(data.index)):
    file_name = data.loc[i, "file_name"]
    name = data.loc[i, "name"]
    if pd.isna(name):
        pass
    elif len(re.findall(",", name)) > 1:
        # drop this row 
        rows_to_drop.append(i)
        # append a row to the df for each new name 
        split_name = name.split(",")
        for new_name in split_name:
            data = data.append({"file_name": file_name, "name": new_name}, ignore_index = True)

# %%
data = data.drop(rows_to_drop)

# %%
# now, loop through dataframe, get rid of special characters and abbreviations we don't want
# and re-parse the names into first middle and last

# %%
data.reset_index(drop = True, inplace = True)

# %%
data = pd.read_excel("ner_deduplicated_8_13_20.xlsx")

# %%
from nameparser import HumanName

# %%
# strip names of periods, dashes, acronyms and other common words before parsing 
for i in range(2500, len(data.index)):
    name = data.loc[i, "name"]
    if pd.isna(name):
        continue
        
    new_name = re.sub("[A-Z]{4,}|NYC|AMH|DTW|DRS|STL|STC|ABT|[Aa]ffadavits|( th)$|( then)$|( rd)$|( nd)$|( widow)$|daughter|ONT|photoed|scanned|papers|Papers|\.|-|(?-i:A[LKSZRAEP]|BC|C[AOT]|D[EC]|F[LM]|G[AU]|HI|I[ADLN]|K[SY]|LA|M[AEHINOPST]|N[CDEHJMVY]|O[HKR]|P[ARW]|RI|S[CD]|T[NX]|UT|V[AIT]|W[AIVY])$", "", name).strip()
    
    
    # for one word names, this algorithm doesn't really do anything. can't tell if it's a first or last name
    # so I'm just going to leave those columns as blank
    if len(new_name.split()) == 1:
        continue
        
    # use nameparser package to extract rest of names
    name = HumanName(new_name)
    data.loc[i, 'title'] = name.title
    data.loc[i, 'first_name'] = name.first
    data.loc[i, 'middle_name'] = name.middle
    data.loc[i, 'last_name'] = name.last
    data.loc[i, 'suffix'] = name.suffix
    
    # for some reason nameparser translates something like JD Smith to firstname JD last name Smith, 
    # instead of first name J middle name D last name Smith. so here I manually fix that
    if (re.match("[A-Z]{2,3}", name.first)) and not name.middle:
        data.loc[i, 'first_name'] = name.first[0]
        data.loc[i, 'middle_name'] = name.first[1:]

# %%
# get rid of abbreviations beforehand and afterward
count = 0
for name in data['name']:
    # if it has at least two capital letters at the end 
    if pd.isna(name):
        pass
    elif re.match("[A-Za-z ]+ [A-Z]{2,}$", name):
        # check to make sure it doesn't end with our prespecified things
        if re.search("SR|JR|PHD|MD", name):
            pass
        # else get rid of it
        else:
            name = re.sub("[ A-Z]{2,}$", "", name)
            data.loc[count, "name"] = name
    count = count + 1

# %%
### matching within these files
# within a file: same first and last name where one has a middle name and one doesn't,
# or one has a prefix and one doesn't, or middle initial is the same as middle name
# OR same first name and last initial or vice versa
# OR same first name and last name differ at most by a letter
# OR first name matches and middle name in one is the same as last name in other (like a maiden name)
# note: more lenient because within a file it's a lot more likely that J Smith and John Smith are the same person
# if they're both referred to in a file

# across files: 
# if first initial + full last name, a match can be made if the name is rare 
# or if there's a matching middle initial
# if full first name + last initial, not enough unless we have a middle match 
# if full first and last names, depends on the commonality of the names

# %%
# the Broyd, Borderland files are causing problems because they're almost identical
# create a new file name for those that are found in both 

subset1 = data[data['file_name']=="Broyld, Borderland Blacks Rochester and St. Catharines 1850-1860 note-s.txt"]
subset2 = data[data['file_name']=="Broyld, Borderland Blacks Rochester and St. Catharines notes including revisions.docx"]

lst1 = set(subset1['name'])
lst2 = set(subset2['name'])

overlap = list(lst1 & lst2)

for i in range(len(data.index)):
    filename = data.loc[i, 'file_name']
    name = data.loc[i, 'name']
    
    if (filename in ["Broyld, Borderland Blacks Rochester and St. Catharines 1850-1860 note-s.txt", "Broyld, Borderland Blacks Rochester and St. Catharines notes including revisions.docx"]) & (name in overlap):
        data.loc[i, 'file_name'] = "In both Broyld, Borderland Blacks Rochester and St. Catharines 1850-1860 note-s.txt and Broyld, Borderland Blacks Rochester and St. Catharines notes including revisions.docx"

# %%
# deduplicate 

# temporarily remove all na rows, since they will match with each other
nonna_subset = data[~data['first_name'].isna()]

# get rid of duplicates that share all parts of the name in the same file 
duplicates = nonna_subset[nonna_subset.duplicated(['file_name', 'first_name', 'middle_name', 'last_name', 'suffix'])]
data = data.drop(duplicates.index)

# %%
master = pd.read_excel("current_master_11_4_20.xlsx")

# %%
# define common, medium, and rare names based on the master file which has more data
common_first_names = master['First.Name'].value_counts()[master['First.Name'].value_counts() > 60]
medium_first_names = master['First.Name'].value_counts()[(master['First.Name'].value_counts() <= 60) & (master['First.Name'].value_counts() >= 3)]
rare_first_names = master['First.Name'].value_counts()[master['First.Name'].value_counts() < 3]

# %%
common_last_names = master['Last.Name'].value_counts()[master['Last.Name'].value_counts() > 100]
medium_last_names = master['Last.Name'].value_counts()[(master['Last.Name'].value_counts() <= 100) & (master['Last.Name'].value_counts() >= 3)]
rare_last_names = master['Last.Name'].value_counts()[master['Last.Name'].value_counts() < 3]

# %%
# matching

new_data = pd.DataFrame(columns = ['File Name 1', 'File Name 2', 'Name 1', 'Name 2', 'ID 1', 'ID 2'])


for i in range(len(data.index)):
     
        
    filename = data.loc[i, 'file_name']
    name = data.loc[i, 'name']
    firstname = data.loc[i, 'first_name']
    middlename = data.loc[i, 'middle_name']
    lastname = data.loc[i, 'last_name']
    suffix = data.loc[i, 'suffix']
    id1 = data.loc[i, 'ID #']

    for j in range(i + 1, len(data.index)):

        match = False
        
        filename2 = data.loc[j, 'file_name']
        name2 = data.loc[j, 'name']
        firstname2 = data.loc[j, 'first_name']
        middlename2 = data.loc[j, 'middle_name']
        lastname2 = data.loc[j, 'last_name']
        suffix2 = data.loc[j, 'suffix']
        id2 = data.loc[j, 'ID #']
        
        # if it's blank for a first or last name, that's not enough to make a match
        if pd.isna(lastname) | pd.isna(lastname2) | pd.isna(firstname) | pd.isna(firstname2):
            continue

        
        # last name
        last_distance = textdistance.levenshtein(lastname, lastname2)
        if lastname in common_last_names:
            last_common = "common"
        elif lastname in medium_last_names:
            last_common = "medium"
        else:
            last_common = "rare"

        # first name
        first_distance = textdistance.levenshtein(firstname, firstname2)
        if firstname in common_first_names:
            first_common = "common"
        elif lastname in medium_last_names:
            first_common = "medium"
        else:
            first_common = "rare"
                
        # middle name        
        if pd.isna(middlename) | pd.isna(middlename2):
            middle_distance = 100
        else:
            middle_distance = textdistance.levenshtein(middlename, middlename2)
            
        # rules for within a file name = more lenient, since it's more likely to be about the same person
        if filename == filename2:
            if (len(firstname) == 1) & (len(lastname) == 1):
                pass
            # if first name is an initial, S. Bair or S. B. 
            elif len(firstname) == 1:
                # S. Bair
                if firstname2.startswith(firstname) & ((last_distance<=1) | (lastname.startswith(lastname2))):
                    match = True
                            
            # repeate if last name is an initial, Sophie B. 
            elif len(lastname) == 1:
                if lastname2.startswith(lastname) & ((first_distance<=1) | (firstname.startswith(firstname2))):
                    match = True
            
            # no initials, just similar names
            elif (first_distance <=1) & (last_distance <=1):
                match = True
                # if one has a suffix of jr or senior, then it's not a match
                if (suffix in ["jr, Jr., Jr, JR, jr., JR., sr, Sr., Sr, SR, sr., SR."]) | (suffix2 in ["jr, Jr., Jr, JR, jr., JR., sr, Sr., Sr, SR, sr., SR."]):
                    match = False
                    
            # maiden name check 
            elif first_distance <=1:
                if (middlename == lastname2) | (middlename2 == lastname):
                    match = True
                    
            # Make sure middle names match if they exist
            if (pd.notna(middlename)) & (pd.notna(middlename2)):
                if len(middlename) == 1 | len(middlename2) == 1:
                    if middlename.startswith(middlename2[0]):
                        pass
                    else:
                        match = False
                else:
                    if middle_distance > 1:
                        match = False

                    
            
        # outside a file it's a bit tricker, have to take commonality into effect 
        else:
            # if just initials (S.B.), not enough to make a match
            if (len(firstname) == 1) & (len(lastname) == 1):
                pass
            
            # if first initial + full last name, a match can be made if the name is rare 
            # or if there's a matching middle initial
            elif len(firstname) == 1:
                if (firstname2.startswith(firstname)) & (last_distance == 0):
                    if  last_common == "rare":
                        match = True
                    elif (pd.notna(middlename)) & (pd.notna(middlename2)):
                        if len(middlename) == 1 | len(middlename2) == 1:
                            if middlename.startswith(middlename2[0]):
                                match = True
                        else:
                            if middle_distance == 0:
                                match = True
                            
            # if full first name + last initial, not enough unless we have a middle match 
            elif len(lastname) == 1:
                if (lastname2.startswith(lastname)) & (first_distance == 0):
                    if (pd.notna(middlename)) & (pd.notna(middlename2)):
                        if len(middlename) == 1 | len(middlename2) == 1:
                            if middlename.startswith(middlename2[0]):
                                match = True
                        else:
                            if middle_distance == 0:
                                match = True

            # now, if full names on both    
            elif (first_distance <=1) & (last_distance <=1):
                if (first_common == "rare") | (last_common == "rare"):
                    match = True
                elif (first_common == "common") & (last_common == "common"):
                    # first and last names must be a perfect match
                    if (first_distance == 0) & (last_distance == 0):
                        # if there's middle names, they must be a perfect match 
                        if middle_distance == 0:
                            match = True
                        # if no middle names, number in the file name must match 
                        elif middle_distance == 100:
                            if (len(re.sub("[^0-9]", "", filename)) > 0) & (re.sub("[^0-9]", "", filename) == re.sub("[^0-9]", "", filename2)):
                                match = True
                else:
                    if middle_distance == 0:
                        match = True
                    elif (len(re.sub("[^0-9]", "", filename)) > 0) & (re.sub("[^0-9]", "", filename) == re.sub("[^0-9]", "", filename2)):
                        match = True
                        
        if match:
            new_data = new_data.append({'File Name 1': filename, 'File Name 2': filename2, 'Name 1': name, 'Name 2': name2, 'ID 1': id1, 'ID 2': id2}, ignore_index = True)

# %%
new_data.head()
# Out:
#                                             File Name 1  \
# 0                Anderson Ruffin Abbott Papers TRL.docx
# 1                Anderson Ruffin Abbott Papers TRL.docx
# 2                      Globe Democrat from Guylaine.txt
# 3                      Globe Democrat from Guylaine.txt
# 4                      Globe Democrat from Guylaine.txt
# 5                      Globe Democrat from Guylaine.txt
# 6                      Globe Democrat from Guylaine.txt
# 7                      Globe Democrat from Guylaine.txt
# 8                      Globe Democrat from Guylaine.txt
# 9                      Globe Democrat from Guylaine.txt
# 10             Black Abolitionists Archive UD Mercy.txt
# 11             Black Abolitionists Archive UD Mercy.txt
# 12             Black Abolitionists Archive UD Mercy.txt
# 13           Flett, African British Columbia women.docx
# 14               Anderson Ruffin Abbott Papers TRL.docx
# 15                     Globe Democrat from Guylaine.txt
# 16    Norval Johnson Heritage Collection STC Public ...
# 17    Johnson, Martha A widow of Aaron B Johnson 5 M...
# 18    Johnson, Martha A widow of Aaron B Johnson 5 M...
# 19    Johnson, Martha A widow of Aaron B Johnson 5 M...
# 20    Johnson, Martha A widow of Aaron B Johnson 5 M...
# 21    Johnson, Martha A widow of Aaron B Johnson 5 M...
# 22    Johnson, Martha widow of Aaron B Johnson 5th M...
# 23    Department of Education Select Subject Files R...
# 24    Department of Education Select Subject Files R...
# 25                      Family trees – Black Mecca.docx
# 26    Alexander, Ellen widow of George Alexander 102...
# 27    Alexander, Ellen widow of George Alexander 102...
# 28      Smith, Isaac alias John Smith 102 USCI NARA.txt
# 29             Black Abolitionists Archive UD Mercy.txt
# ...                                                 ...
# 1630  Sawyer, Elizabeth widow of Thomas Sawyer 102 U...
# 1631               Talbert, William H 102 USCI NARA.txt
# 1632               Talbert, William H 102 USCI NARA.txt
# 1633               Talbert, William H 102 USCI NARA.txt
# 1634  Norval Johnson Heritage Collection STC Public ...
# 1635      Sherry Edmunds-Flett Research Collection.docx
# 1636  Broyld, Borderland Blacks Rochester and St. Ca...
# 1637  Alexander, Ellen widow of George Alexander 102...
# 1638  Alexander, Ellen widow of George Alexander 102...
# 1639  Alexander, Ellen widow of George Alexander 102...
# 1640                    Alfred, John 102 USCI NARA.docx
# 1641                    Alfred, John 102 USCI NARA.docx
# 1642  Goins, Rachel widow of Daniel Goins 102 USCI N...
# 1643  Binder Chatham Township Census 1871 Wills - CW...
# 1644  Davis, Elizabeth widow of Charles Davis 102 US...
# 1645  Johnson, Sarah, mother of Isaac Wilson 20th US...
# 1646  Binder Chatham Township Census 1871 Wills - CW...
# 1647      Minor child of Willis Stark 115 USCI NARA.txt
# 1648  Anderson Ruffin Abbott Collection additions S2...
# 1649  Anderson Ruffin Abbott Collection additions S2...
# 1650  Anderson Ruffin Abbott Collection additions S2...
# 1651  Anderson Ruffin Abbott Collection additions S2...
# 1652  Arenson notes on Richard Reid Citizens Sojourn...
# 1653  Arenson notes on Richard Reid Citizens Sojourn...
# 1654  Arenson notes on Richard Reid Citizens Sojourn...
# 1655           Black Abolitionists Archive UD Mercy.txt
# 1656           Black Abolitionists Archive UD Mercy.txt
# 1657                    Family trees – Black Mecca.docx
# 1658             Anderson Ruffin Abbott Papers TRL.docx
# 1659  Taylor, Cornelia widow of Henry Taylor 18th US...
#
#                                             File Name 2  \
# 0                      Globe Democrat from Guylaine.txt
# 1                            Guylaine Petrin notes.docx
# 2                            Guylaine Petrin notes.docx
# 3                      Globe Democrat from Guylaine.txt
# 4     Arenson notes on Richard Reid Citizens Sojourn...
# 5     Arenson notes on Richard Reid Citizens Sojourn...
# 6              Black Abolitionists Archive UD Mercy.txt
# 7     Arenson notes on Richard Reid Citizens Sojourn...
# 8     Arenson notes on Richard Reid Citizens Sojourn...
# 9              Black Abolitionists Archive UD Mercy.txt
# 10           Flett, African British Columbia women.docx
# 11             Black Abolitionists Archive UD Mercy.txt
# 12             Black Abolitionists Archive UD Mercy.txt
# 13           Flett, African British Columbia women.docx
# 14    Arenson notes on Richard Reid Citizens Sojourn...
# 15                     Globe Democrat from Guylaine.txt
# 16       Niagara Falls NY Public Library scrapbooks.txt
# 17    Johnson, Martha A widow of Aaron B Johnson 5 M...
# 18    Johnson, Martha widow of Aaron B Johnson 5th M...
# 19    Johnson, Martha widow of Aaron B Johnson 5th M...
# 20    Johnson, Martha widow of Aaron B Johnson 5th M...
# 21    Johnson, Martha widow of Aaron B Johnson 5th M...
# 22    Johnson, Martha widow of Aaron B Johnson 5th M...
# 23                      Family trees – Black Mecca.docx
# 24                          Individual Files BNHS_M.txt
# 25                          Individual Files BNHS_M.txt
# 26      Smith, Isaac alias John Smith 102 USCI NARA.txt
# 27    West, Elizabeth widow of William West 102 USCI...
# 28    West, Elizabeth widow of William West 102 USCI...
# 29           Flett, African British Columbia women.docx
# ...                                                 ...
# 1630               Talbert, William H 102 USCI NARA.txt
# 1631               Talbert, William H 102 USCI NARA.txt
# 1632               Talbert, William H 102 USCI NARA.txt
# 1633               Talbert, William H 102 USCI NARA.txt
# 1634  Norval Johnson Heritage Collection STC Public ...
# 1635      Sherry Edmunds-Flett Research Collection.docx
# 1636                   Globe Democrat from Guylaine.txt
# 1637                    Alfred, John 102 USCI NARA.docx
# 1638  Goins, Rachel widow of Daniel Goins 102 USCI N...
# 1639  West, Elizabeth widow of William West 102 USCI...
# 1640  Goins, Rachel widow of Daniel Goins 102 USCI N...
# 1641  West, Elizabeth widow of William West 102 USCI...
# 1642  West, Elizabeth widow of William West 102 USCI...
# 1643                        Wills binder -- BNHS_M.docx
# 1644                    Shaw, Thomas 102 USCI NARA.docx
# 1645  Michigan Historical Records Survey Records WPA...
# 1646  Brenda Lenore Shadd Edmonds Wallace Travis int...
# 1647            Vancouver Public Library materials.docx
# 1648  Arenson notes on Richard Reid Citizens Sojourn...
# 1649           Black Abolitionists Archive UD Mercy.txt
# 1650                    Family trees – Black Mecca.docx
# 1651                   Globe Democrat from Guylaine.txt
# 1652           Black Abolitionists Archive UD Mercy.txt
# 1653                    Family trees – Black Mecca.docx
# 1654                   Globe Democrat from Guylaine.txt
# 1655                    Family trees – Black Mecca.docx
# 1656                   Globe Democrat from Guylaine.txt
# 1657                   Globe Democrat from Guylaine.txt
# 1658           Black Abolitionists Archive UD Mercy.txt
# 1659  Taylor, Cornelia widow of Henry Taylor 18th US...
#
#                           Name 1                   Name 2   ID 1   ID 2
# 0                      AR Abbott              A.R. Abbott  51756  55891
# 1                      AR Abbott              A.R. Abbott  51756  56094
# 2                    A.R. Abbott              A.R. Abbott  55891  56094
# 3                   A.T. Augusta     A.T. Augusta, L.M.B.  55892  55893
# 4                   A.T. Augusta          Alex T. Augusta  55892  51964
# 5                   A.T. Augusta     Alexander T. Augusta  55892  51967
# 6                   A.T. Augusta      Alexander T Augusta  55892  52676
# 7           A.T. Augusta, L.M.B.          Alex T. Augusta  55893  51964
# 8           A.T. Augusta, L.M.B.     Alexander T. Augusta  55893  51967
# 9           A.T. Augusta, L.M.B.      Alexander T Augusta  55893  52676
# 10                    AH Francis            A. H. Francis  52672  55377
# 11                    AH Francis      Abner Francis DELNY  52672  52674
# 12                    AH Francis            Allan Francis  52672  52678
# 13                 A. H. Francis            Abner Francis  55377  55378
# 14                   AR Garrison       Albert R. Garrison  51757  51963
# 15                    A.H. Judah        Adolphus H. Judah  55894  55895
# 16                  A.A. Mossell            Aaron Mossell  57993  57920
# 17               Aaron B Johnson            Aaron Johnson  57013  57014
# 18               Aaron B Johnson          Aaron B Johnson  57013  57065
# 19               Aaron B Johnson            Aaron Johnson  57013  57066
# 20                 Aaron Johnson          Aaron B Johnson  57014  57065
# 21                 Aaron Johnson            Aaron Johnson  57014  57066
# 22               Aaron B Johnson            Aaron Johnson  57065  57066
# 23                Abel Cockfield           Abel Cockfield  54850  55172
# 24                Abel Cockfield           Abel Cockfield  54850  56902
# 25                Abel Cockfield           Abel Cockfield  55172  56902
# 26                    Abner Byrd               Abner Byrd  51007  59391
# 27                    Abner Byrd               Abner Byrd  51007  60132
# 28                    Abner Byrd               Abner Byrd  59391  60132
# 29           Abner Francis DELNY            Abner Francis  52674  55378
# ...                          ...                      ...    ...    ...
# 1630             William Talbert  William Talbert JR WDSR  58875  59511
# 1631             William Talbert      William Talbert III  59509  59510
# 1632             William Talbert  William Talbert JR WDSR  59509  59511
# 1633         William Talbert III  William Talbert JR WDSR  59510  59511
# 1634              William Taylor    William Wilson Taylor  58210  58211
# 1635       William Albert Turner           William Turner  59224  59225
# 1636          William J. Watkins       William J. Watkins  53633  55961
# 1637                William West             William West  51021  51026
# 1638                William West             William West  51021  56021
# 1639                William West             William West  51021  60157
# 1640                William West             William West  51026  56021
# 1641                William West             William West  51026  60157
# 1642                William West             William West  56021  60157
# 1643             William Whipper          William Whipper  52665  60347
# 1644              William Wilson           William Wilson  54804  58953
# 1645        William Henry Wilson     William Henry Wilson  57218  57686
# 1646              Williams Shadd           Williams Shadd  52666  52886
# 1647                Willis Stark             Willis Stark  57725  59975
# 1648        Wilson Ruffin Abbott            Wilson Abbott  51753  52271
# 1649        Wilson Ruffin Abbott            Wilson Abbott  51753  52725
# 1650        Wilson Ruffin Abbott            Wilson Abbott  51753  55209
# 1651        Wilson Ruffin Abbott            Wilson Abbott  51753  55962
# 1652               Wilson Abbott            Wilson Abbott  52271  52725
# 1653               Wilson Abbott            Wilson Abbott  52271  55209
# 1654               Wilson Abbott            Wilson Abbott  52271  55962
# 1655               Wilson Abbott            Wilson Abbott  52725  55209
# 1656               Wilson Abbott            Wilson Abbott  52725  55962
# 1657               Wilson Abbott            Wilson Abbott  55209  55962
# 1658               Wilson Ruffin            Wilson Ruffin  51864  52726
# 1659  Mrs Winfield Scott Hancock  Winfield Scott Hancocks  59558  59559
#
# [1660 rows x 6 columns]

# %%
new_data.to_excel("ner_9_4_20_2.xlsx")

# %%
#### matching between ner file and master

# %%
# First, do name preprocessing for everything because the file is taking forever to run 

def preprocess_data(name):
    name_not_nan = pd.notna(name)
    if name_not_nan:
        if len(name) == 0:
            firstname = np.nan
    return(name)

def preprocess_master(first_name, last_name):
    
    name = str(first_name) + " " + str(last_name)
    myname = HumanName(name)
    firstname2 = myname.first
    middlename2 = myname.middle
    lastname2 = myname.last
    
    if firstname2 == "nan":
        firstname2 = np.nan
    if middlename2 == "nan":
        middlename2 = np.nan
    if lastname2 == "nan":
        lastname2 = np.nan
        
    if pd.notna(firstname2):
        if(len(firstname2) > 2):
            # at beginning: i.e. SElizabeth
            if (re.match("^[A-Z]{2}", firstname2)) and not (re.match("[^[^a-z]*$", firstname2)) and not myname.middle:
                firstname2 = myname.first[0]
                middlename2 = myname.first[1:]
            # at the end: ElizabethJE
            elif firstname2[-1].isupper() and firstname2[-2].isupper()and not (re.match("[^[^a-z]*$", firstname2)) and not myname.middle:
                firstname2 = myname.first[0:-2]
                middlename2 = myname.first[-2:]
            elif firstname2[-1].isupper() and not (re.match("[^[^a-z]*$", firstname2)) and not myname.middle:
                firstname2 = myname.first[0:-1]
                middlename2 = myname.first[-1:]
    
        if re.search("\.",  firstname2):
            for mymatch in re.finditer("\.",  firstname2):
                s = mymatch.start() - 1
                if s == 0:
                    firstname2 = myname.first[0]
                    middlename2 = myname.first[1:]
                else:
                    firstname2 = myname.first[0:s]
                    middlename2 = myname.first[s:]
                break

    firstname2_not_nan = pd.notna(firstname2)
    middlename2_not_nan = pd.notna(middlename2)
    lastname2_not_nan = pd.notna(lastname2)

    if firstname2_not_nan:
        firstname2 = "".join(e for e in firstname2 if e.isalnum())
        firstname2 = firstname2.lower()
        if len(firstname2) == 0:
            firstname2 = np.nan
    if middlename2_not_nan:
        middlename2 = "".join(e for e in middlename2 if e.isalnum())
        middlename2 = middlename2.lower()
        if len(middlename2) == 0:
            middlename2 = np.nan
    if lastname2_not_nan:
        lastname2 = "".join(e for e in lastname2 if e.isalnum()) 
        lastname2 = lastname2.lower()
        if len(lastname2) == 0:
            lastname2 = np.nan
            
    return(firstname2, middlename2, lastname2)

# %%
fast_data = data.filter(['unique_id', 'source', 'Last.Name', 'First.Name'])
fast_master = master.filter(['unique_id', 'source', 'Last.Name', 'First.Name'])

# %%
fast_data['First.Name'] =  fast_data['First.Name'].apply(preprocess_data)
fast_data['Last.Name'] =  fast_data['Last.Name'].apply(preprocess_data)

# %%
#fast_master['first_name', 'middle_name', 'last_name'] = fast_master[['Last.Name', 'First.Name']].apply(preprocess_master, axis = 0)
for i in range(len(fast_master.index)):
    lastname = fast_master.loc[i, 'Last.Name']
    firstname = fast_master.loc[i, 'First.Name']
    result = preprocess_master(firstname, lastname)
    fast_master.loc[i, 'Last.Name'] = result[2]
    #fast_master.loc[i, 'Middle.Name'] = result[1]
    fast_master.loc[i, 'First.Name'] = result[0]

# %%
fast_data = fast_data[fast_data['First.Name'].notna()]
fast_data = fast_data[fast_data['Last.Name'].notna()]
fast_data.reset_index(inplace = True, drop = True)

fast_master = fast_master[fast_master['First.Name'].notna()]
fast_master = fast_master[fast_master['Last.Name'].notna()]
fast_master.reset_index(inplace = True, drop = True)

# %%
fast_data["First.Name"] = fast_data["First.Name"].str.lower()
fast_data["Last.Name"] = fast_data["Last.Name"].str.lower()

# %%
# changing the format: 9/4/20
# updated to make it more lenient: 10/21/20
# changing for victoria files 11/14/20


new_data = pd.DataFrame(columns = ['ID 1', 'ID 2'])


for i in range(len(fast_data.index)):
             
    firstname = fast_data.loc[i, 'First.Name']
    firstname = firstname.split(" ")[0]
    #middlename = fast_data.loc[i, 'middle_name']
    lastname = fast_data.loc[i, 'Last.Name']
    
    #middlename_not_nan = pd.notna(middlename)
    
    if lastname in common_last_names:
        last_common = "common"
    elif lastname in medium_last_names:
        last_common = "medium"
    else:
        last_common = "rare"
        
    if firstname in common_first_names:
        first_common = "common"
    elif lastname in medium_last_names:
        first_common = "medium"
    else:
        first_common = "rare"
    
    for j in range(len(fast_master.index)):

        match = False
        
        firstname2 = fast_master.loc[j, 'First.Name']
        firstname = firstname.split(" ")[0]
        #middlename2 = fast_master.loc[j, 'Middle.Name']
        lastname2 = fast_master.loc[j, 'Last.Name']
            
        # if just initials (S.B.), not enough to make a match
        if (len(firstname) == 1) & (len(lastname) == 1):
            continue
     
        # last name
        last_distance = textdistance.levenshtein(lastname, lastname2)
        
        # first name
        first_distance = textdistance.levenshtein(firstname, firstname2)
                
#         # middle name
#         middlename2_not_nan = pd.notna(middlename2)
#         if middlename_not_nan & middlename2_not_nan:
#             middle_distance = textdistance.levenshtein(middlename, middlename2)
#         else:
#             middle_distance = 100

        # if first initial + full last name, a match can be made if the name isn't common 
        # or if there's a matching middle initial
        if len(firstname) == 1:
            if (firstname2.startswith(firstname)) & (last_distance == 0):
                if last_common != "common":
                    match = True
   
        # if full names for both 
        elif (first_distance <=1) & (last_distance <=1):
            match = True

        if match:
            id1 = fast_data.loc[i, 'unique_id']
            id2 = fast_master.loc[j, 'unique_id']
                
            new_data = new_data.append({'ID 1': id1, 'ID 2': id2}, ignore_index = True)

# %%
master = pd.concat([master, data])

# %%
final_data = pd.DataFrame(columns = master.columns)
for i in range(len(new_data)):
    id1 = new_data.loc[i, 'ID 1']
    row1 = master[master['unique_id'] == id1]

    id2 = new_data.loc[i, 'ID 2']
    row2 = master[master['unique_id'] == id2]
    final_data = final_data.append(row1)
    final_data = final_data.append(row2)
    final_data = final_data.append(pd.Series(), ignore_index=True)

# %%
victoria.to_excel("victoria_11_14_20_3.xlsx")

# %%
new_data = pd.read_excel("ner_10_24_20.xlsx")

# %%
final_data = pd.DataFrame(columns = ['ID 1', 'ID 2', 'Name 1', 'First Name 2', 'Last Name 2', 'Source 1', 'Source 2', 'Census.Year', 'State/Province', 'County', 
                                     'Place', 'Household Joint ID', 'Joint ID for Matched Records',
                                     'CalculatedBirthYear', 'Age', 'Sex',
                                     'Color..Race.or.Ethnicity', 'Match?'])


for i in range(len(new_data.index)):
    id1 = new_data.loc[i, 'ID 1']
    id2 = new_data.loc[i, 'ID 2']
    
    file1 = data[data['ID #'] == id1]
    file2 = master[master['unique_id'] == id2]
    
    name1 = file1['name'].values[0]
    firstname2 = file2['First.Name'].values[0]
    lastname2 = file2['Last.Name'].values[0]
    
    source1 = file1['file_name'].values[0]
    source2 = file2['source'].values[0]
    
    final_data = final_data.append({'ID 1': id1, 'ID 2': id2, 
                                    'Name 1': name1, 'First Name 2': firstname2, 'Last Name 2': lastname2, 
                                   'Source 1': source1, 'Source 2': source2, 
                                   'Census.Year': file2['Census.Year'].values[0], 
                                    'State/Province': file2['State/Province'].values[0], 
                                    'County': file2['County'].values[0],
                                     'Place': file2['Place'].values[0],
                                    'Household Joint ID': file2['Household Joint ID'].values[0], 
                                    'Joint ID for Matched Records': file2['Joint ID for Matched Records'].values[0],
                                     'CalculatedBirthYear': file2['CalculatedBirthYear'].values[0], 
                                    'Age': file2['Age'].values[0], 'Sex': file2['Sex'].values[0],
                                     'Color..Race.or.Ethnicity': file2['Color..Race.or.Ethnicity'].values[0]}, ignore_index = True)

# %%
final_data.head()
# Out:
#        ID 1   ID 2                   Name 1     First Name 2 Last Name 2  \
# 0     51756   2491                AR Abbott         Anderson      Abbott
# 1     51756  50952                AR Abbott      Anderson R       Abbott
# 2     51756  50937                AR Abbott  Anderson Ruffin      Abbott
# 3     51756  50943                AR Abbott  Anderson Ruffin      Abbott
# 4     51756   2122                AR Abbott        ANDERSONR      ABBOTT
# 5     51756   2486                AR Abbott             ARON      ABBOTT
# 6     55891   2491              A.R. Abbott         Anderson      Abbott
# 7     55891  50952              A.R. Abbott      Anderson R       Abbott
# 8     55891  50937              A.R. Abbott  Anderson Ruffin      Abbott
# 9     55891  50943              A.R. Abbott  Anderson Ruffin      Abbott
# 10    55891   2122              A.R. Abbott        ANDERSONR      ABBOTT
# 11    55891   2486              A.R. Abbott             ARON      ABBOTT
# 12    56094   2491              A.R. Abbott         Anderson      Abbott
# 13    56094  50952              A.R. Abbott      Anderson R       Abbott
# 14    56094  50937              A.R. Abbott  Anderson Ruffin      Abbott
# 15    56094  50943              A.R. Abbott  Anderson Ruffin      Abbott
# 16    56094   2122              A.R. Abbott        ANDERSONR      ABBOTT
# 17    56094   2486              A.R. Abbott             ARON      ABBOTT
# 18    52672  16905               AH Francis            ALLEN     FRANCIS
# 19    52672  16927               AH Francis          ALVARAE     FRANCIS
# 20    52672  16906               AH Francis              AMY     FRANCIS
# 21    52672  16928               AH Francis            ANNIE     FRANCIS
# 22    55377  16905            A. H. Francis            ALLEN     FRANCIS
# 23    55377  16927            A. H. Francis          ALVARAE     FRANCIS
# 24    55377  16906            A. H. Francis              AMY     FRANCIS
# 25    55377  16928            A. H. Francis            ANNIE     FRANCIS
# 26    57993  33462             A.A. Mossell           AARONA     MOSSELL
# 27    51408  33463            N. F. Mossell          NATHANF     MOSSELL
# 28    51408  33464            N. F. Mossell          NATHANF     MOSSELL
# 29    57013  25197          Aaron B Johnson            AARON     JOHNSON
# ...     ...    ...                      ...              ...         ...
# 2486  56924  38067            William Riley          WILLIAM       RILEY
# 2487  56924  38087            William Riley          WILLIAM       RILEY
# 2488  57354  38885           William Rogers          WILLIAM      ROGERS
# 2489  52576  40020            William Sears        WILLIAMM.       SEARS
# 2490  52264  42597          William Spencer          WILLIAM     SPENCER
# 2491  56083  42597          William Spencer          WILLIAM     SPENCER
# 2492  56795  42597          William Spencer          WILLIAM     SPENCER
# 2493  53315  43229    William Henry Stewart        WILLIAMH.     STEWART
# 2494  53315  43272    William Henry Stewart        WILLIAMH.     STEWART
# 2495  52267  45415          William Thurman          WILLIAM     THURMAN
# 2496  54254  46938            William Walls          WILLIAM       WALLS
# 2497  53317  47545    William James Watkins          WILLIAM     WATKINS
# 2498  53317  47546    William James Watkins          WILLIAM     WATKINS
# 2499  54255  47545          William Watkins          WILLIAM     WATKINS
# 2500  54255  47546          William Watkins          WILLIAM     WATKINS
# 2501  52269  48093          William Wheeler         WilliamA     Wheeler
# 2502  57332  49943             William Winn          WILLIAM        WINN
# 2503  56246  50223            William Woods          WILLIAM       WOODS
# 2504  56246  50224            William Woods          WILLIAM       WOODS
# 2505  52270   7990  Williams Jennings Bryan          WILLIAM       BRYAN
# 2506  52270   7996  Williams Jennings Bryan          WILLIAM      BRYANT
# 2507  52270   8000  Williams Jennings Bryan          WILLIAM      BRYANT
# 2508  52270  39311  Williams Jennings Bryan          WILLIAM        RYAN
# 2509  58434  49905            Willis Wilson           WILLIS      WILSON
# 2510  56796   2193  Inf.- Camp William Penn          WILLIAM        PENN
# 2511  56796   2194  Inf.- Camp William Penn          WILLIAM        PENN
# 2512  56796  35603  Inf.- Camp William Penn          WILLIAM        PENN
# 2513  55210  48760          Wilson Williams           WILSON    WILLIAMS
# 2514  57919  34075       Winfield S Newcomb     Windfield S.     Newcomb
# 2515  51541    407        Zachariah Jackson        ZACHARIAH     JACKSON
#
#                                                Source 1  \
# 0                Anderson Ruffin Abbott Papers TRL.docx
# 1                Anderson Ruffin Abbott Papers TRL.docx
# 2                Anderson Ruffin Abbott Papers TRL.docx
# 3                Anderson Ruffin Abbott Papers TRL.docx
# 4                Anderson Ruffin Abbott Papers TRL.docx
# 5                Anderson Ruffin Abbott Papers TRL.docx
# 6                      Globe Democrat from Guylaine.txt
# 7                      Globe Democrat from Guylaine.txt
# 8                      Globe Democrat from Guylaine.txt
# 9                      Globe Democrat from Guylaine.txt
# 10                     Globe Democrat from Guylaine.txt
# 11                     Globe Democrat from Guylaine.txt
# 12                           Guylaine Petrin notes.docx
# 13                           Guylaine Petrin notes.docx
# 14                           Guylaine Petrin notes.docx
# 15                           Guylaine Petrin notes.docx
# 16                           Guylaine Petrin notes.docx
# 17                           Guylaine Petrin notes.docx
# 18             Black Abolitionists Archive UD Mercy.txt
# 19             Black Abolitionists Archive UD Mercy.txt
# 20             Black Abolitionists Archive UD Mercy.txt
# 21             Black Abolitionists Archive UD Mercy.txt
# 22           Flett, African British Columbia women.docx
# 23           Flett, African British Columbia women.docx
# 24           Flett, African British Columbia women.docx
# 25           Flett, African British Columbia women.docx
# 26    Norval Johnson Heritage Collection STC Public ...
# 27        Alvin D McCurdy fonds AO after recovered.docx
# 28        Alvin D McCurdy fonds AO after recovered.docx
# 29    Johnson, Martha A widow of Aaron B Johnson 5 M...
# ...                                                 ...
# 2486                        Individual Files BNHS_M.txt
# 2487                        Individual Files BNHS_M.txt
# 2488                     Lewis, Thomas 31 USCI NARA.txt
# 2489  Berry now Ross, Emily former widow of Lewis Be...
# 2490  Arenson notes on Richard Reid Citizens Sojourn...
# 2491                  Grandy, Isaac 102nd USCI NARA.txt
# 2492                         Historically Speaking.docx
# 2493  In both Broyld, Borderland Blacks Rochester an...
# 2494  In both Broyld, Borderland Blacks Rochester an...
# 2495  Arenson notes on Richard Reid Citizens Sojourn...
# 2496                 Carter, Charles 102 USCI NARA.docx
# 2497  In both Broyld, Borderland Blacks Rochester an...
# 2498  In both Broyld, Borderland Blacks Rochester an...
# 2499                 Carter, Charles 102 USCI NARA.docx
# 2500                 Carter, Charles 102 USCI NARA.docx
# 2501  Arenson notes on Richard Reid Citizens Sojourn...
# 2502  Lewis, Martha A. widow of John Lewis 20th USCI...
# 2503                         Guylaine Petrin notes.docx
# 2504                         Guylaine Petrin notes.docx
# 2505  Arenson notes on Richard Reid Citizens Sojourn...
# 2506  Arenson notes on Richard Reid Citizens Sojourn...
# 2507  Arenson notes on Richard Reid Citizens Sojourn...
# 2508  Arenson notes on Richard Reid Citizens Sojourn...
# 2509                       Pelham Family Papers DPL.txt
# 2510                         Historically Speaking.docx
# 2511                         Historically Speaking.docx
# 2512                         Historically Speaking.docx
# 2513                    Family trees – Black Mecca.docx
# 2514  Newcomb, David father of Winfield S Newcomb 31...
# 2515      Alvin D McCurdy fonds AO after recovered.docx
#
#                     Source 2 Census.Year State/Province  \
# 0                       USCT        1864            NaN
# 1                1881 Canada        1881        Ontario
# 2                1861 Canada        1861        Ontario
# 3                1871 Canada        1871        Ontario
# 4                      16890        1920             NY
# 5                        519        1860             MI
# 6                       USCT        1864            NaN
# 7                1881 Canada        1881        Ontario
# 8                1861 Canada        1861        Ontario
# 9                1871 Canada        1871        Ontario
# 10                     16890        1920             NY
# 11                       519        1860             MI
# 12                      USCT        1864            NaN
# 13               1881 Canada        1881        Ontario
# 14               1861 Canada        1861        Ontario
# 15               1871 Canada        1871        Ontario
# 16                     16890        1920             NY
# 17                       519        1860             MI
# 18    1880 IPUMS 100% sample        1880             CA
# 19                     15544        1920             VI
# 20    1880 IPUMS 100% sample        1880             CA
# 21                     11188        1910             MA
# 22    1880 IPUMS 100% sample        1880             CA
# 23                     15544        1920             VI
# 24    1880 IPUMS 100% sample        1880             CA
# 25                     11188        1910             MA
# 26                      6613        1900             PA
# 27                     16315        1920             PA
# 28                     13805        1910             PA
# 29    1880 IPUMS 100% sample        1880             MI
# ...                      ...         ...            ...
# 2486  1880 IPUMS 100% sample        1880            NaN
# 2487                     975        1860             NY
# 2488                   17152        1920             OH
# 2489  1880 IPUMS 100% sample        1880             NY
# 2490                     709        1860             MA
# 2491                     709        1860             MA
# 2492                     709        1860             MA
# 2493  1880 IPUMS 100% sample        1880             OH
# 2494  1880 IPUMS 100% sample        1880             NY
# 2495                   17106        1920             OH
# 2496                   15820        1920             MT
# 2497                   17507        1920             IL
# 2498                   11462        1910             IL
# 2499                   17507        1920             IL
# 2500                   11462        1910             IL
# 2501                     NaN        1850             MA
# 2502  1880 IPUMS 100% sample        1880            NaN
# 2503  1880 IPUMS 100% sample        1880            NaN
# 2504  1880 IPUMS 100% sample        1880            NaN
# 2505  1880 IPUMS 100% sample        1880             NY
# 2506  1880 IPUMS 100% sample        1880            NaN
# 2507  1880 IPUMS 100% sample        1880            NaN
# 2508                    8253        1900             OH
# 2509                   12387        1910             MI
# 2510  1880 IPUMS 100% sample        1880             IN
# 2511                   10090        1900             IN
# 2512  1880 IPUMS 100% sample        1880            NaN
# 2513  1880 IPUMS 100% sample        1880            NaN
# 2514               31st USCT        1864            NaN
# 2515                     NaN        1864     CanadaWest
#
#                      County              Place Household Joint ID  \
# 0                       NaN                NaN                118
# 1                       NaN            Toronto                118
# 2     Toronto St Johns Ward            Toronto                118
# 3     Toronto St James Ward            Toronto                118
# 4                     BRONX              BRONX                118
# 5                     WAYNE          MONGUAGON                NaN
# 6                       NaN                NaN                118
# 7                       NaN            Toronto                118
# 8     Toronto St Johns Ward            Toronto                118
# 9     Toronto St James Ward            Toronto                118
# 10                    BRONX              BRONX                118
# 11                    WAYNE          MONGUAGON                NaN
# 12                      NaN                NaN                118
# 13                      NaN            Toronto                118
# 14    Toronto St Johns Ward            Toronto                118
# 15    Toronto St James Ward            Toronto                118
# 16                    BRONX              BRONX                118
# 17                    WAYNE          MONGUAGON                NaN
# 18                      NaN      San Francisco                NaN
# 19                  STCROIX  NORTHSIDEAQUARTER                NaN
# 20                      NaN      San Francisco                NaN
# 21                MIDDLESEX          CAMBRIDGE                NaN
# 22                      NaN      San Francisco                NaN
# 23                  STCROIX  NORTHSIDEAQUARTER                NaN
# 24                      NaN      San Francisco                NaN
# 25                MIDDLESEX          CAMBRIDGE                NaN
# 26             PHILADELPHIA       PHILADELPHIA                NaN
# 27             PHILADELPHIA       PHILADELPHIA                NaN
# 28             PHILADELPHIA       PHILADELPHIA                NaN
# 29                    WAYNE            DETROIT                NaN
# ...                     ...                ...                ...
# 2486                    NaN                NaN                NaN
# 2487                NIAGARA            NIAGARA                NaN
# 2488               CUYAHOGA          CLEVELAND                NaN
# 2489                    NaN            Buffalo                NaN
# 2490              WORCESTER            WESTUGH                NaN
# 2491              WORCESTER            WESTUGH                NaN
# 2492              WORCESTER            WESTUGH                NaN
# 2493                    NaN           Columbus                NaN
# 2494                    NaN          Rochester                NaN
# 2495               CUYAHOGA          CLEVELAND                NaN
# 2496                   HILL        SCHOOLDIST5                NaN
# 2497                   COOK            CHICAGO                NaN
# 2498                   COOK            CHICAGO                NaN
# 2499                   COOK            CHICAGO                NaN
# 2500                   COOK            CHICAGO                NaN
# 2501                    NaN               Lynn                NaN
# 2502                    NaN                NaN                NaN
# 2503                    NaN                NaN                NaN
# 2504                    NaN                NaN                NaN
# 2505                    NaN           New York                NaN
# 2506                    NaN                NaN                NaN
# 2507                    NaN                NaN                NaN
# 2508                  LUCAS             TOLEDO                NaN
# 2509                  WAYNE            DETROIT                NaN
# 2510               JENNINGS             BIGGER                NaN
# 2511                 RIPLEY         WASHINGTON                NaN
# 2512                    NaN                NaN                NaN
# 2513                    NaN                NaN                NaN
# 2514                    NaN                NaN                NaN
# 2515                  Essex            Windsor                NaN
#
#      Joint ID for Matched Records CalculatedBirthYear Age Sex  \
# 0                            1311                1842  22   M
# 1                            1317                1877   4   M
# 2                            1311                1838  23   M
# 3                            1311                1836  35   M
# 4                            1317                1879  41   M
# 5                             NaN                1829  31   M
# 6                            1311                1842  22   M
# 7                            1317                1877   4   M
# 8                            1311                1838  23   M
# 9                            1311                1836  35   M
# 10                           1317                1879  41   M
# 11                            NaN                1829  31   M
# 12                           1311                1842  22   M
# 13                           1317                1877   4   M
# 14                           1311                1838  23   M
# 15                           1311                1836  35   M
# 16                           1317                1879  41   M
# 17                            NaN                1829  31   M
# 18                            NaN                1878   2   M
# 19                            NaN                1907  13   F
# 20                            NaN                1880   0   F
# 21                            NaN                1883  27   F
# 22                            NaN                1878   2   M
# 23                            NaN                1907  13   F
# 24                            NaN                1880   0   F
# 25                            NaN                1883  27   F
# 26                            NaN                1863  37   M
# 27                            NaN                1857  63   M
# 28                            NaN                1905   5   M
# 29                            NaN                1850  30   M
# ...                           ...                 ...  ..  ..
# 2486                          NaN                1856  24   M
# 2487                          NaN                1830  30   M
# 2488                          NaN                1897  23   M
# 2489                          NaN                1852  28   M
# 2490                          NaN                1849  11   M
# 2491                          NaN                1849  11   M
# 2492                          NaN                1849  11   M
# 2493                          NaN                1880   0   M
# 2494                          NaN                1877   3   M
# 2495                          NaN                1882  38   M
# 2496                          NaN                1873  47   M
# 2497                          NaN                1871  49   M
# 2498                          NaN                1908   2   M
# 2499                          NaN                1871  49   M
# 2500                          NaN                1908   2   M
# 2501                          NaN                1850   0   M
# 2502                          NaN                1850  30   M
# 2503                          NaN                1830  50   M
# 2504                          NaN                1868  12   M
# 2505                          NaN                1845  35   M
# 2506                          NaN                1835  45   M
# 2507                          NaN                1862  18   M
# 2508                          NaN                1860  40   M
# 2509                          NaN                1860  50   M
# 2510                            ?                1862  18   M
# 2511                            ?                1862  38   M
# 2512                          NaN                1810  70   M
# 2513                          NaN                1874   6   M
# 2514                          NaN                1845  19   M
# 2515                          164                1847  17   M
#
#      Color..Race.or.Ethnicity Match?
# 0                         NaN    NaN
# 1                         NaN    NaN
# 2                         NaN    NaN
# 3                     African    NaN
# 4                           M    NaN
# 5                           B    NaN
# 6                         NaN    NaN
# 7                         NaN    NaN
# 8                         NaN    NaN
# 9                     African    NaN
# 10                          M    NaN
# 11                          B    NaN
# 12                        NaN    NaN
# 13                        NaN    NaN
# 14                        NaN    NaN
# 15                    African    NaN
# 16                          M    NaN
# 17                          B    NaN
# 18     Mulatto(BlackandWhite)    NaN
# 19                          B    NaN
# 20     Mulatto(BlackandWhite)    NaN
# 21                          B    NaN
# 22     Mulatto(BlackandWhite)    NaN
# 23                          B    NaN
# 24     Mulatto(BlackandWhite)    NaN
# 25                          B    NaN
# 26                          B    NaN
# 27                          B    NaN
# 28                          M    NaN
# 29                      Black    NaN
# ...                       ...    ...
# 2486                    White    NaN
# 2487                        M    NaN
# 2488                        M    NaN
# 2489   Mulatto(BlackandWhite)    NaN
# 2490                        M    NaN
# 2491                        M    NaN
# 2492                        M    NaN
# 2493   Mulatto(BlackandWhite)    NaN
# 2494                    Black    NaN
# 2495                        B    NaN
# 2496                        M    NaN
# 2497                        B    NaN
# 2498                        B    NaN
# 2499                        B    NaN
# 2500                        B    NaN
# 2501                    White    NaN
# 2502                    Black    NaN
# 2503                    White    NaN
# 2504   Mulatto(BlackandWhite)    NaN
# 2505                    Black    NaN
# 2506                    Black    NaN
# 2507                    Black    NaN
# 2508                        B    NaN
# 2509                        B    NaN
# 2510                        B    NaN
# 2511                        B    NaN
# 2512                    Black    NaN
# 2513   Mulatto(BlackandWhite)    NaN
# 2514                    black    NaN
# 2515                        C    NaN
#
# [2516 rows x 18 columns]

# %%
final_data.to_excel("ner_matches_tocheck_10_29_20.xlsx")

# %%
victoria = pd.read_excel("victoria_11_14_20.xlsx")

# %%
# for victoria files we have birth year, so here we drop any matches in which the discrepancies in the birth years
# are too large to be feasible (>10 yrs difference)
to_drop = []
for i in range(0, len(victoria), 3):
    year1 = victoria.loc[i, 'CalculatedBirthYear']
    year2 = victoria.loc[i + 1, 'CalculatedBirthYear']
    if pd.notna(year1) & pd.notna(year2):
        if isinstance(year1, int) & isinstance(year2, int):
            if abs(int(year1) - int(year2)) > 10:
                to_drop.append(i)
                to_drop.append(i + 1)
                to_drop.append(i + 2)
victoria = victoria.drop(to_drop)
